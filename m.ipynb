# %%
import pandas as pd

df = pd.read_csv('gowtham2.csv')

df['authors'] = df['authors'].replace({'Gowtham Rameshamesh': 'Gowtham Ramesh'}, regex=True)

df.to_csv('gowtham2.csv', index=False)

df
# Out:
#     Unnamed: 0.1  Unnamed: 0  \
# 0              2           2
# 1              3           3
# 2              5           5
# 3              7           7
# 4              9           9
# 5             10          10
# 6             11          11
# 7             12          12
# 8             13          13
# 9             14          14
# 10            15          15
# 11            16          16
# 12            17          17
# 13            18          18
# 14            19          19
# 15            20          20
# 16            21          21
#
#                                               authors aggregationType  \
# 0                      Dharan Nidhin S,Gowtham Ramesh            Book
# 1         Johnson Shanoop,Gowtham Ramesh,Nair Anand R            Book
# 2   Gowtham Ramesh,Sanjay S P,Shandilya Shishir Ku...         Journal
# 3   Ravikumar Sourav,Vinod Dayanand,Gowtham Ramesh...         Journal
# 4   Alampalli Ramu Nikhil,Bandarupalli Mohana Sai,...            Book
# ...
